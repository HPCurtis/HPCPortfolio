# %% [markdown]
# # One sample t-test

# %%
# Load in relevant analysis packages.
using CSV, DataFrames, HypothesisTests, Plots

# %% [markdown]
# ## Import data

# %%
# Read in data for onesample t-test
url = "https://raw.githubusercontent.com/HPCurtis/HPCPortfolio/main/Data/Mehr%20Song%20and%20Spelke%202016%20Experiment%201.csv"
df = CSV.read(download(url), DataFrame);

# %% [markdown]
# ## Data cleaning and EDA

# %%
# The data for the specific experiment is in the first 32 rows of the dataframe
red_df = df[1:32, :];
# check if id are correct by looking at last 2 rows id's.
last(red_df, 2)
# Out:
# 2×153 DataFrame
#  Row │ id     study_code  exp1   exp2   exp3   exp4     exp5     dob        do ⋯
#      │ Int64  String7     Int64  Int64  Int64  String1  String1  String15   St ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   131  "LUL"           1      0      0                    17-Oct-12  06 ⋯
#    2 │   132  "LUL"           1      0      0                    01-Dec-12  08
#                                                              145 columns omitted

# %% [markdown]
# ## Plot data

# %%
histogram(red_df[:,:Baseline_Proportion_Gaze_to_Singer],
          label = false, xlim = [0.1, 1], ylim = [0, 15])

# %%
# Calculate one sample t-test with p-value and confidence interval
# using OneSampleTTest
results = OneSampleTTest(red_df[:,:Baseline_Proportion_Gaze_to_Singer], 0)
# Out:
# One sample t-test
# -----------------
# Population details:
#     parameter of interest:   Mean
#     value under h_0:         0
#     point estimate:          0.521097
#     95% confidence interval: (0.4573, 0.5849)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:   32
#     t-statistic:              16.657344006181578
#     degrees of freedom:       31
#     empirical standard error: 0.03128329911458993

# %%
results.df
# Out:
# 0

# %% [markdown]
# # Result interpretation
#
# The APA offers a clear result presentation style for the reuslts of classic statistical test results. This style is adopted here. Baseline gaze proprtion scores were analysed using a one sample t-test with population $\mu$ parameter for Hypohtesis test set to 0 with baseline gaze proportion scores having (M = .52, SD = .03) t(32) = 16.68, p = 0.001, with 95% CI [.46, .58].

# %% [markdown]
# ### Statistical Mistake within this analysis

# %% [markdown]
# # References
#
# Sassenhagen, J., & Alday, P. M. (2016). A common misapplication of statistical inference: Nuisance control with null-hypothesis significance tests. Brain and language, 162, 42-45.
